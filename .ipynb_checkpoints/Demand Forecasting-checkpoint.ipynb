# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
import datetime
import pandas as pd
# %matplotlib inline

from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.ensemble import RandomForestRegressor
# Out:
# 2.8.0

# %%
TS_Data = pd.read_csv("TS_data.csv")
RF_Data = pd.read_csv("RF_data.csv")

# %%
TS_Data
# Out:
#       Unnamed: 0                        Description       Dates  Quantity
# 0              0          ALARM CLOCK BAKELIKE RED   2010-12-01      19.0
# 1              1          ALARM CLOCK BAKELIKE RED   2010-12-02      88.0
# 2              2          ALARM CLOCK BAKELIKE RED   2010-12-03      51.0
# 3              3          ALARM CLOCK BAKELIKE RED   2010-12-04       0.0
# 4              4          ALARM CLOCK BAKELIKE RED   2010-12-05      38.0
# ...          ...                                ...         ...       ...
# 5605        5605  WOODEN PICTURE FRAME WHITE FINISH  2011-12-05      15.0
# 5606        5606  WOODEN PICTURE FRAME WHITE FINISH  2011-12-06       8.0
# 5607        5607  WOODEN PICTURE FRAME WHITE FINISH  2011-12-07      42.0
# 5608        5608  WOODEN PICTURE FRAME WHITE FINISH  2011-12-08      10.0
# 5609        5609  WOODEN PICTURE FRAME WHITE FINISH  2011-12-09       4.0
#
# [5610 rows x 4 columns]

# %%
RF_Data
# Out:
#       Unnamed: 0                        Description       Dates  Quantity  \
# 0              0          ALARM CLOCK BAKELIKE RED   2010-12-01      19.0
# 1              1          ALARM CLOCK BAKELIKE RED   2010-12-02      88.0
# 2              2          ALARM CLOCK BAKELIKE RED   2010-12-03      51.0
# 3              3          ALARM CLOCK BAKELIKE RED   2010-12-04       0.0
# 4              4          ALARM CLOCK BAKELIKE RED   2010-12-05      38.0
# ...          ...                                ...         ...       ...
# 5605        5605  WOODEN PICTURE FRAME WHITE FINISH  2011-12-05      15.0
# 5606        5606  WOODEN PICTURE FRAME WHITE FINISH  2011-12-06       8.0
# 5607        5607  WOODEN PICTURE FRAME WHITE FINISH  2011-12-07      42.0
# 5608        5608  WOODEN PICTURE FRAME WHITE FINISH  2011-12-08      10.0
# 5609        5609  WOODEN PICTURE FRAME WHITE FINISH  2011-12-09       4.0
#
#       Invoice  CustomerID  Relative_UnitPrice
# 0           3           3            4.157368
# 1           6           6            3.750000
# 2           2           2            4.027647
# 3           0           0            0.000000
# 4           7           7            3.750000
# ...       ...         ...                 ...
# 5605        6           4            4.779333
# 5606        3           3            3.305000
# 5607        6           6            3.141429
# 5608        3           3            3.553000
# 5609        1           1            4.960000
#
# [5610 rows x 7 columns]

# %%
Dates = TS_Data["Dates"].unique()

# %%
Products = ['WHITE HANGING HEART T-LIGHT HOLDER',
 'REGENCY CAKESTAND 3 TIER',
 'JUMBO BAG RED RETROSPOT',
 'ASSORTED COLOUR BIRD ORNAMENT',
 'NATURAL SLATE HEART CHALKBOARD ']

# %%
TS_Prod = {}
RF_Prod = {}
for product in Products:
    TS_Prod[product] = np.array(TS_Data[TS_Data["Description"] == product]["Quantity"])
    RF_Prod[product] = RF_Data[RF_Data["Description"] == product][["Quantity","Invoice","CustomerID","Relative_UnitPrice"]]

# %%
def windowed_dataset(series, window_size, shuffle_buffer):
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
    dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
    #dataset = dataset.batch(batch_size).prefetch(1)
    return zip(*list(dataset.as_numpy_iterator()))

# %%
def createmodel(n_layers = 2, activation_func = "linear", opt = "sgd"):
    model = keras.models.Sequential()
    
    model.add(keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]))
    for i in range(n_layers):
        if i== n_layers - 1:
            model.add(keras.layers.Bidirectional(tf.keras.layers.LSTM(50)))
        else:
            model.add(keras.layers.Bidirectional(tf.keras.layers.LSTM(50, return_sequences=True)))
            
    model.add(keras.layers.Dense(1, activation=activation_func))
    model.add(keras.layers.Lambda(lambda x: x * 100.0))
    model.compile(optimizer = opt, loss='mae', metrics = ["mae"]) 
    
    return model

model =  KerasRegressor(model=createmodel,n_layers = 2, activation_func = "linear", opt = "sgd",verbose=False,random_state=0)

# %%
activation_funcs = ['linear', 'relu', 'tanh'] 
optimizers = ["rmsprop", "adam", "sgd"]
param_grid = {"n_layers":[2,3], "activation_func" : activation_funcs, "opt" : optimizers, "batch_size" : [5], "epochs" : [100]}
cv = ShuffleSplit(n_splits=1, test_size=0.09, random_state=0)
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv=cv)

# %%
window_size = 31
shuffle_buffer = 342
model_hp = {'Product': [],'activation_func': [],
 'batch_size': [],
 'epochs': [],
 'n_layers': [],
 'opt': []}
for product in Products[:1]:
    train = TS_Prod[product][:-window_size]
    X, y = windowed_dataset(train,window_size,shuffle_buffer)

    grid.fit(np.array(X),np.array(y))

    best = dict(grid.best_params_)
    model_hp['Product'].append(product)
    for key in best.keys() :
        model_hp[key].append(best[key])


pd.DataFrame(model_hp).to_csv("hyperparameters.csv",index=False)

# %%
grid.best_estimator_
# Out:
# KerasRegressor(
# 	model=<function createmodel at 0x000001DC54B64670>
# 	build_fn=None
# 	warm_start=False
# 	random_state=0
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=5
# 	validation_batch_size=None
# 	verbose=False
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=100
# 	n_layers=2
# 	activation_func=relu
# 	opt=rmsprop
# )

# %% [markdown]
# print(model)
# model.activation_func = 'linear'
# model.batch_size =  5
# model.n_layers = 3
# model.epochs = 100
# model.opt = 'sgd'

# %% [markdown]
# model

# %% [markdown]
# train = TS_Prod[Products[0]][:-window_size]
# X, y = windowed_dataset(train,window_size,shuffle_buffer)
# model.fit(X,y)

# %%
forecast = []
for time in range(len(train) - window_size):
    forecast.append(grid.best_estimator_.predict(train[time:time+window_size][np.newaxis]))

# %%
pred = np.array(list(zip(*forecast))[0])

# %%
len(pred)
# Out:
# 312

# %%
test_predLSTM = []
for time in range(len(TS_Prod[Products[0]]) - 2*window_size,len(TS_Prod[Products[0]]) - window_size):
    test_predLSTM.append(grid.best_estimator_.predict(TS_Prod[Products[0]][time:time+window_size][np.newaxis]))

# %%
len(test_predLSTM)
# Out:
# 31

# %%
test_predLSTM = np.array(list(zip(*test_predLSTM))[0])

# %%
test_actual = TS_Prod[Products[0]][-window_size:]

# %%
plt.figure(figsize=(20,10))
plt.plot(test_actual)
plt.plot(test_predLSTM)
print(np.sum(abs(test_actual - test_predLSTM)) / test_actual.shape[0])
# Out:
# 77.24168897444203

# %%
actual_train = train[window_size:]

# %%
actual
# Out:
#        8.800e+01, 1.570e+02, 1.040e+02, 5.600e+01, 1.320e+02, 0.000e+00,
#        1.600e+02, 3.100e+01, 8.000e+00, 5.800e+01, 4.900e+02, 6.200e+01,
#        0.000e+00, 1.070e+02, 4.900e+01, 3.200e+01, 9.100e+01, 1.300e+02,
#        3.200e+01, 0.000e+00, 8.900e+01, 7.300e+01, 1.210e+02, 6.800e+01,
#        7.100e+01, 1.600e+01, 0.000e+00, 5.200e+01, 1.040e+02, 8.700e+01,
#        3.800e+01, 1.500e+01, 6.000e+00, 0.000e+00, 1.500e+01, 4.200e+02,
#        1.220e+02, 6.100e+01, 9.500e+01, 2.400e+01, 0.000e+00, 4.200e+01,
#        0.000e+00, 6.300e+01, 3.700e+01, 1.120e+02, 1.660e+02, 0.000e+00,
#        1.600e+01, 9.500e+01, 1.600e+02, 1.300e+01, 2.100e+01, 2.900e+01,
#        0.000e+00, 8.900e+01, 1.170e+02, 1.330e+02, 7.900e+01, 1.460e+02,
#        1.010e+02, 0.000e+00, 8.100e+01, 4.200e+01, 3.930e+02, 1.100e+01,
#        2.600e+01, 1.190e+02, 0.000e+00, 6.900e+01, 4.800e+01, 2.100e+01,
#        1.250e+02, 8.000e+01, 1.130e+02, 0.000e+00, 2.100e+01, 2.300e+01,
#        1.800e+01, 4.900e+01, 1.300e+01, 2.800e+01, 0.000e+00, 2.600e+01,
#        1.270e+02, 4.000e+01, 1.900e+01, 2.430e+02, 1.150e+02, 0.000e+00,
#        5.500e+01, 3.100e+01, 1.500e+01, 1.200e+01, 1.800e+01, 1.300e+01,
#        0.000e+00, 6.300e+01, 1.600e+01, 1.600e+01, 2.000e+01, 1.170e+02,
#        8.400e+01, 0.000e+00, 1.160e+02, 1.520e+02, 3.900e+01, 8.000e+01,
#        1.265e+03, 8.100e+01, 0.000e+00, 7.400e+01, 3.400e+01, 1.110e+02])

# %%
len(actual)
# Out:
# 312

# %%
residuals = actual - pred

# %%
np.sum(abs(residuals))/residuals.shape[0]
# Out:
# 26.74969718567072

# %%
RF_Data = RF_Prod[Products[0]][window_size:][:-window_size]

# %%
rf = RandomForestRegressor()

# %%
reg = rf.fit(RF_Data,residuals)

# %%
reg.score(RF_Data,residuals)
# Out:
# 0.9541506586319973

# %%
reg.predict(RF_Data)
# Out:
# array([ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  2.80963099e+01,
#         5.69420494e+00,  4.04812179e+01,  7.72234334e+01,  0.00000000e+00,
#         4.96864010e+00,  1.03956853e+01,  1.51238564e+03,  2.87676625e+01,
#         4.82835738e+00,  1.95638999e+01,  0.00000000e+00, -2.81669169e+00,
#         1.87950975e+01,  7.04545051e+00,  2.59854192e+00,  1.93828140e+01,
#         1.09124559e+01,  0.00000000e+00, -3.77925636e+00, -1.68592513e+01,
#        -3.13000093e+01, -2.79067202e+01, -2.79139675e+00,  9.75666718e+00,
#         0.00000000e+00,  8.00814484e+00,  4.58306015e+00,  2.01531184e+01,
#         1.71133478e+01,  4.06969297e+00,  2.10226598e+01,  0.00000000e+00,
#         9.89919698e+00,  2.26309200e+00, -1.16969553e+01,  4.44561582e+00,
#        -1.16620832e+01,  2.56253256e+01,  0.00000000e+00,  5.34654724e+00,
#        -4.99215698e+00,  0.00000000e+00, -4.20262032e+01,  6.25160980e+00,
#         1.85551453e+02, -1.13587265e+01, -4.38977661e+01,  5.86179543e+00,
#         0.00000000e+00, -3.43997421e+01,  6.21538544e+00, -2.09626312e+01,
#         7.97225952e+00, -1.09063644e+01,  2.71348801e+01,  0.00000000e+00,
#         2.20321960e+01,  1.27195511e+01,  8.00000000e+00, -1.74960327e+00,
#         6.86568604e+01,  4.73954010e+00,  0.00000000e+00, -1.55602646e+01,
#         3.30779266e+00, -1.02672462e+01, -3.03832626e+01, -1.11235046e+01,
#         5.61992645e+00,  0.00000000e+00,  5.09226990e+00,  8.87944794e+00,
#         9.95194244e+00,  7.61250305e+00,  1.18639984e+01,  1.24505687e+01,
#         0.00000000e+00, -2.74722290e+00,  2.63589249e+01,  5.05085754e+00,
#         8.09176636e+00,  1.50000000e+01,  6.00000000e+00,  0.00000000e+00,
#         3.64549541e+00,  7.33463745e+01,  7.21118164e+00, -1.08714447e+01,
#        -1.34721680e+01,  2.40000000e+01,  0.00000000e+00, -1.12041016e+01,
#         0.00000000e+00,  8.04180527e+00,  1.07390041e+01,  8.52178192e+00,
#         3.58232727e+01,  0.00000000e+00, -1.21350670e+00,  4.97021484e+00,
#         7.23756409e+00,  2.12351990e+00,  1.04389143e+01,  2.39066348e+01,
#         0.00000000e+00, -1.19031525e+01,  2.18134766e+01,  1.66768951e+01,
#        -2.07699738e+01, -3.15834503e+01, -2.53287277e+01,  0.00000000e+00,
#         3.88342285e+00, -6.09043884e+00, -7.35223389e+00,  1.10000000e+01,
#         3.98087502e+00,  5.90408516e+01,  0.00000000e+00, -1.29026031e+01,
#         1.24342499e+01, -7.80513763e+00, -1.98602600e+01, -1.77613297e+01,
#        -1.40319672e+01,  0.00000000e+00, -3.76572037e+00,  2.73903656e+00,
#         1.75998934e+01,  2.00631847e+01,  2.58278561e+00,  2.80000000e+01,
#         0.00000000e+00, -6.87662888e+00,  3.22679672e+01,  1.80830765e+00,
#        -1.09556427e+01, -3.63035583e+00,  3.29613647e+01,  0.00000000e+00,
#        -9.65946960e+00,  6.01027107e+00, -2.72957001e+01,  1.20000000e+01,
#         4.31277561e+00,  1.30000000e+01,  0.00000000e+00,  1.36653557e+01,
#         1.60000000e+01,  1.60000000e+01,  2.00000000e+01,  3.19498672e+01,
#         4.00628662e+01,  0.00000000e+00, -7.14139557e+00,  1.46019287e+01,
#         7.18456268e-01, -4.68795471e+01,  5.49386536e+02,  5.65098038e+01,
#         0.00000000e+00,  1.22895355e+01, -1.29366264e+01,  1.78506393e+01])

# %%
RF_test = RF_Prod[Products[0]][-window_size:]

# %%
test_predRF = reg.predict(RF_test)

# %%
test_pred = test_predLSTM + test_predRF

# %%
plt.figure(figsize=(20,10))
plt.plot(test_actual)
plt.plot(test_pred)
print(np.sum(abs(test_actual - test_pred)) / test_actual.shape[0])
# Out:
# 75.92165944661376

# %%
test_actual
# Out:
# array([113.,  71., 128.,   0.,  67., 374., 349., 160.,  90., 103.,   0.,
#         96.,  36.,  87.,  91., 111., 225.,   0.,   8., 133., 117., 239.,
#         41., 117.,   0.,   8., 249.,  21., 177.,  58.,   0.])
